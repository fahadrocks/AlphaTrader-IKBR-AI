# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Download multiple stocks at once
tickers = ["AAPL", "TSLA", "MSFT", "NVDA"]
data = yf.download(tickers, period="1y", interval="1d")

print(data.head(20))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-06-03  202.466782  202.964806  200.165912  200.554370  46381600
# 2025-06-04  202.018539  205.425023  201.301383  202.108180  43604000
# 2025-06-05  199.837204  203.940919  199.359090  202.695858  55126100
# 2025-06-06  203.114197  204.887162  201.251591  202.197834  46607700
# 2025-06-09  200.653961  205.185985  199.229619  203.582346  72862600
# 2025-06-10  201.869156  203.542525  199.777463  199.807343  54672600
# 2025-06-11  197.994522  203.691921  197.625989  202.695872  60989900
# 2025-06-12  198.412857  198.890956  196.580131  198.293336  43904600
# 2025-06-13  195.673706  199.578214  194.926670  198.940744  51447300
# 2025-06-16  197.635941  197.904878  195.783290  196.520371  43020700
# ...
